# %% [markdown]
# **DESARROLLO TAREAS MATEMÁTICAS DISCRETAS 2 - 2024-1**
#
# **Profesor:** Arles Ernesto Rodríguez Portela
#
# **Estudiante:** Omar David Toledo Leguizamón

# %% [markdown]
# # Tarea 1
#
# Determinar si la operación $⋆$ es una operación binaria sobre el conjunto dado $S$:
#
# a. $S = \mathbb{R}$ , $a⋆b = \dfrac{a}{a^2 + b^2}$
#
# b. $S = \{1,-2,3,2,-4\}$ , $a⋆b = |b|$
#
# c. $S = \mathbb{R}$ , $a⋆b = a$

# %% [markdown]
# ## Desarrollo
#
# ### a. $S = \mathbb{R}$ , $a⋆b = \dfrac{a}{a^2 + b^2}$
#
# **Contraejemplo**
#
# Vamos a definir dos valores $a,b \in \mathbb{R}$
#
# $$0 \in \mathbb{R} \,\, \wedge  \,\, a=b=0 \,\, \Longrightarrow a,b \in \mathbb{R}$$
#
# Aplicamos nuestra operación $a⋆b$
#
# $$a⋆b = 0⋆0 = \dfrac{0}{0^2 + 0^2} = \dfrac{0}{0} \notin \mathbb{R} \Longrightarrow a⋆b \notin \mathbb{R}$$
#
# Encontramos una pareja $(a,b) \in \mathbb{R} \times \mathbb{R}$ tal que $a⋆b \notin \mathbb{R}$
#
# $$\therefore ⋆ \text{ NO es una operación binaria}$$
#
#
# ### b. $S = \{1,-2,3,2,-4\}$ , $a⋆b = |b|$
#
# Dado que tenemos un conjunto finito, podemos realizar todas las operaciones sin problema. Por practicidad, vamos a organizarlo en una tabla de $n \times n$ donde $n = |S|$
#
# Siendo $a$ el valor de la fila y $b$ el valor de la columna, la siguiente tabla tiene los resultados de la operación $a⋆b$
#
# \begin{array}{|r|c|c|c|c|c|}
#     \hline
#      S \times S & \textbf{1} & \textbf{-2} & \textbf{3} & \textbf{2} & \textbf{-4} \\
#     \hline
#     \textbf{1} & 1 & 2 & 3 & 2 & 4 \\
#     \hline
#     \textbf{-2} & 1 & 2 & 3 & 2 & 4 \\
#     \hline
#     \textbf{3} & 1 & 2 & 3 & 2 & 4 \\
#     \hline
#     \textbf{2} & 1 & 2 & 3 & 2 & 4 \\
#     \hline
#     \textbf{-4} & 1 & 2 & 3 & 2 & 4 \\
#     \hline
# \end{array}
#
# Podemos denotar que en la quinta columna (Asociada a $b=-4$) obtenemos un resultado que no está en el conjunto original $S$
#
# $$a⋆ -4 = 4 \notin S \,\,\,\, \forall a \in S$$
#
# $$\therefore ⋆ \text{ NO es una operación binaria}$$
#
# ### c. $S = \mathbb{R}$ , $a⋆b = a$
#
# No es necesario ser muy metódicos ni formales para denotar que si se tiene por precondición que los operandos $a$ y $b$ pertenecen al conjunto $S$ y el resultado de la operación es uno de esos mismos operandos (En este caso $a$), se puede concluir que $a⋆b$ tambien pertenece al conjunto $S$
#
# $$a,b \in S \,\, \wedge \,\, a⋆b = a \Longrightarrow a⋆b \in S$$
#
# $$\therefore ⋆ \text{ SI es una operación binaria}$$

# %% [markdown]
# # Tarea 2
#
# Demuestre que $\mathbb{R}−\{1\}$ bajo la operación $a∘b=a+b−ab$ es un grupo.

# %% [markdown]
# ## Desarrollo
#
# Para demostrar que $(\mathbb{R}−\{1\} , ∘)$ es un grupo, debemos determinar que $∘$ es una operación binaria sobre el conjunto, que es una operación asociativa, que existe un elemento identidad y que cada elemento de un conjunto tiene un inverso.
#
# ### ¿Es $∘$ una operación binaria?
#
# Para concluir $∘$ es una operación binaria, necesitamos demostrar que:
#
# $$a,b \in \mathbb{R}−\{1\} \Longrightarrow a ∘ b \in \mathbb{R}−\{1\}$$
#
# En primer lugar, vamos a aprovechar las propiedades de cerradura de la suma $(+)$ y el producto $(\cdot)$ sobre los números reales $(\mathbb{R})$. Estas propiedades son las siguientes:
#
# $$a,b \in \mathbb{R} \Longrightarrow a + b \in \mathbb{R}$$
# $$a,b \in \mathbb{R} \Longrightarrow ab \in \mathbb{R}$$
#
# Adicionalmente, podemos escribir nuestro conjunto $\mathbb{R}−\{1\}$ utlilizando la definición de diferencia entre conjuntos.
#
# $$\mathbb{R}−\{1\} = \{x: x \in \mathbb{R} \wedge x \notin \{1\}\} = \{x: x \in \mathbb{R} \wedge x \neq 1\}$$
#
#
# Podemos denotar en la definición del conjunto, que podemos analizar que el punto clave se encuentra en la *exclusión* del numero 1 del conjunto de los reales. Por lo que el siguiente paso será realizar un análisis por **contradicción**.
#
# Suponemos que:
#
# $$\exists a,b \in \mathbb{R}−\{1\}\,\, (a ∘ b = 1 )$$
#
# $$\exists a,b \neq 1 \,\, (a ∘ b = 1 )$$
#
# Realizamos nuestro desarrollo algebraico:
#
# $$a ∘ b = 1 \Longrightarrow a+b-ab =1$$
#
# \begin{array}{ccccc}
#     a-ab = 1-b & & \lor & &b-ab = 1-a \\
#     a(1-b) = 1-b &&\lor&& b(1-a) = 1-a \\
#     \text{Dado que b}\neq 1 &&\lor&& \text{Dado que a}\neq 1 \\
#     a = \dfrac{1-b}{1-b} &&\lor&& b = \dfrac{1-a}{1-a} \\
#     a = 1 &&\lor&& b = 1
# \end{array}
#
# Dado que obtuvimos que $a = 1 \lor b = 1$ y nuestra suposición era que $a \neq 1 \wedge b \neq 1$, hemos llegado a una **CONTRADICCIÓN**
#
# Por consiguiente, queda demostrado que $a,b \in \mathbb{R}−\{1\} \Longrightarrow a ∘ b \in \mathbb{R}−\{1\}$
#
# $$\therefore ∘ \text{ SI es una operación binaria}$$
#
# ### ¿Es $∘$ una operación asociativa?
#
# Para concluir $∘$ es una operación asociativa, necesitamos demostrar que:
#
# $$a,b,c \in \mathbb{R}−\{1\} \Longrightarrow (a ∘ b) ∘ c = a ∘ (b ∘ c)$$
#
# Realizamos el análisis algebraico
#
# \begin{array}{ccc}
#     (a ∘ b) ∘ c & = &  (a+b - ab) ∘ c & & \\
#                 & = &  a+b - ab + c - (a+b - ab)c & & \\
#                 & = &  a+b - ab + c - (ac+bc - abc) & & \\
#                 & = &  a + b - ab + c - ac - bc + abc & & \\
#                 & = &  a + b + c - bc - ac - ab  + abc & & \\
#                 & = &  a + (b + c - bc) - a(b + c  - bc) & & \\
#                 & = &  a ∘ (b + c - bc) & = & a ∘ (b ∘ c)\\
# \end{array}
#
# Queda demostrado que $a,b,c \in \mathbb{R}−\{1\} \Longrightarrow (a ∘ b) ∘ c = a ∘ (b ∘ c)$
#
# $$\therefore ∘ \text{ SI es una operación asociativa}$$
#
# ### ¿Existe un elemento identidad $(e)$?
#
# Para determinar si existe un elemento identidad, debemos encontrar un elemento que cumpla la siguiente propiedad:
#
# $$\forall_{a \in \mathbb{R}−\{1\}} \exists_{e \in \mathbb{R}−\{1\}} \,\, (a ∘ e = e ∘ a = a)$$
#
# Planteamos el desarrollo algebraico para hallar el elemento identidad
#
# \begin{array}{ccccccc}
#     a ∘ e = a & \Longrightarrow &  a + e - ae = a & & & & e ∘ a = a & \Longrightarrow &  e + a - ea = a & &\\
#               & \Longrightarrow &  e - ae = a - a& & & & & \Longrightarrow &  e - ea = a - a& &\\
#               & \Longrightarrow &  e - ae = 0 & & & &  & \Longrightarrow &  e - ea = 0 & &\\
#               & \Longrightarrow &  e(1-a) = 0 & & & & & \Longrightarrow &  e(1-a) = 0 & &\\
#               &                 & \text{Dado que a}\neq 1 & & & & & & \text{Dado que a}\neq 1 & &\\
#               & \Longrightarrow &  e = 0 & & & & & \Longrightarrow &  e = 0 & &\\
# \end{array}
#
# Encontramos que el elemento $e = 0$ es aquel que cumple que $a ∘ 0 = 0 ∘ a = a \,\,\, \forall_{a \in \mathbb{R}−\{1\}}$
#
# $$\therefore \text{ SI existe un elemento identidad} \,\, (e = 0)$$
#
# ### ¿Existen los elementos inversos?
#
# Para determinar si existen los elementos inversos, debemos encontrar aquellos elementos que satisfacen:
#
# $$\forall_{a \in \mathbb{R}−\{1\}} \exists_{h \in \mathbb{R}−\{1\}} \,\, (a ∘ h = h ∘ a = 0)$$
#
# Planteamos el desarrollo algebraico para hallar el elemento identidad
#
# \begin{array}{ccccccc}
#     a ∘ h = 0 & \Longrightarrow &  a + h - ah = 0 & & & & h ∘ a = 0 & \Longrightarrow &  h + a - ha = 0 & &\\
#               & \Longrightarrow &  h - ah = -a & & & & & \Longrightarrow &  h - ha = -a& &\\
#               & \Longrightarrow &  h(1-a) = -a & & & &  & \Longrightarrow &   h(1-a) = -a & &\\
#               & \Longrightarrow &  h(a-1) = a & & & & & \Longrightarrow &  h(a-1) = a & &\\
#               &                 & \text{Dado que a}\neq 1 & & & & & & \text{Dado que a}\neq 1 & &\\
#               & \Longrightarrow &  h = \dfrac{a}{a-1} & & & & & \Longrightarrow &  h = \dfrac{a}{a-1} & &\\
# \end{array}
#
# Encontramos que el elemento $h = \dfrac{a}{a-1}$ es aquel que cumple $\forall_{a \in \mathbb{R}−\{1\}} \exists_{h \in \mathbb{R}−\{1\}} \,\, (a ∘ h = h ∘ a = 0)$
#
# $$\therefore \text{ SI existen los elementos inversos} \,\, \left( h = \dfrac{a}{a-1} \,\,\, \forall_{a \in \mathbb{R}−\{1\}}\right)$$
#
# ### Finalmente ...
#
# Dado que identificamos que $(\mathbb{R}−\{1\} , ∘)$ cuenta con una operación básica que es asociable; y que cuenta con un elemento identidad y elementos inversos; podemos concluir que el conjunto dado (sobre la operación $∘$) es un **GRUPO**
#
# $$\therefore (\mathbb{R}−\{1\} , ∘) \text{ SI es un grupo} $$

# %% [markdown]
# # Tarea 3
#
# Dado un grupo $(G,⋆)$, y teniendo que $x,y,z \in G$ demuestre que:
#
# a.  Si $x⋆y = x⋆z$, entonces $y=z$ (Ley de cancelación por izquierda)
#
# b.  Si $y⋆x = z⋆x$, entonces $y=z$ (Ley de cancelación por derecha)

# %% [markdown]
# ## Desarrollo
#
# ### a.  Si $x⋆y = x⋆z$, entonces $y=z$ (Ley de cancelación por izquierda)
#
# Para realizar nuestra demostración, vamos a partir de nuestra hipótesis, la cual dice que $x⋆y = x⋆z$, y usaremos las propiedades básicas de los grupos para concluir que $y=z$
#
# \begin{array}{rclcr}
#     x⋆y &=& x⋆z && \text{Hipótesis Inicial} \\
#     x^{-1} ⋆ (x⋆y) &=& x^{-1} ⋆ (x⋆z) && \text{Operamos a ambos lados por el inverso de } x \\
#     (x^{-1} ⋆ x) ⋆y  &=& (x^{-1} ⋆ x)⋆z && \text{Propiedad Asociativa} \\
#     e ⋆y  &=& e ⋆z && \text{Aplicamos definición de Inversa} \\
#     y &=& z && \text{Aplicamos definición de Identidad} \\
# \end{array}
#
# Podemos concluir que:
#
# $$\therefore \forall_{x,y,z \in (G,⋆)} \,\, (x⋆y = x⋆z \Longrightarrow y=z)$$
#
#
# ### b.  Si $y⋆x = z⋆x$, entonces $y=z$ (Ley de cancelación por derecha)
#
# Para realizar nuestra demostración, vamos a partir de nuestra hipótesis, la cual dice que $y⋆x = z⋆x$, y usaremos las propiedades básicas de los grupos para concluir que $y=z$
#
# \begin{array}{rclcr}
#     y⋆x &= &z⋆x && \text{Hipótesis Inicial} \\
#     (y⋆x) ⋆ x^{-1} &=& (z⋆x) ⋆ x^{-1} && \text{Operamos a ambos lados por el inverso de } x \\
#     y⋆(x ⋆ x^{-1})& = &z⋆(x ⋆ x^{-1}) && \text{Propiedad Asociativa} \\
#     y ⋆e  &=& z ⋆e && \text{Aplicamos definición de Inversa} \\
#     y &=& z && \text{Aplicamos definición de Identidad} \\
# \end{array}
#
# Podemos concluir que:
#
# $$\therefore \forall_{x,y,z \in (G,⋆)} \,\, (y⋆x = z⋆x \Longrightarrow y=z)$$

# %% [markdown]
# # Tarea 4
#
# Desarrolle los siguientes ejercicios:
#
# 1- Considerando el grupo de enteros $G=(\mathbb{Z}_4,⨁)$ encuentre el orden de cada elemento de $\mathbb{Z}_4=\{0,1,2,3\}$
#
# 2- Considerando el grupo de enteros $G=(\mathbb{Z}_5,⨁)$ encuentre el orden de cada elemento de $\mathbb{Z}_5=\{0,1,2,3,4\}$
#
# 3-Encuentre el orden de 1 en  $G=(\mathbb{Z},+)$
#
# 4-¿Es $G=(\mathbb{Z}_4,⨁)$ un grupo cíclico? Si lo es, ¿cuáles son sus generadores?

# %% [markdown]
# ## Desarrollo
#
# ### 1. Considerando el grupo de enteros $G=(\mathbb{Z}_4,\oplus)$ encuentre el orden de cada elemento de $\mathbb{Z}_4=\{0,1,2,3\}$
#
# Dado que nuestra opración a analizar es la adición módulo 4, podremos escribir la n-ésima operación de un elemento $x$ consigo mismo de la siguiente forma:
#
# \begin{array}{ccccc}
#     x^{n} &=&\underbrace{x \oplus x \oplus x ...}  &=& n\cdot x\mod 4\\
#     && n\text{-veces} && \\
# \end{array}
#
# Adicionalmente, podemos denotar que el elemento identidad sobre nuestra operación es el 0 $(e = 0)$, ya que:
#
# $$\forall_{x \in \mathbb{Z}_4} \,\, x \oplus 0 =  0 \oplus x = x \mod 4$$
#
# El siguiente paso, es describir el orden de cada uno de los elementos de nuestro conjunto. Para esto, vamos a aprovechar la definición de orden y la definición del módulo:
#
# $$o(x) = n \Longleftrightarrow x^{n} = e$$
#
# $$x \mod n = r \Longleftrightarrow \exists_{k \in \mathbb{Z}} \,\, k\cdot n + r = x$$
#
# Para hallar el orden de cada elemento de nuestro conjunto, podemos aplicar lo siguiente:
#
# \begin{array}{rcl}
#     o(x) = n &\Longleftrightarrow& x^{n} = 0 \\
#     & & n\cdot x\mod 4 = 0 \\
#     & & k\cdot 4 + 0 = n \cdot x \\
#     & & \dfrac{4 \cdot k}{x} = n \\
# \end{array}
#
# Se puede concluir que para todo elemento $x \in \mathbb{Z}_4$, su orden se puede describir como el número entero positivo más pequeño que cumpla $\dfrac{4 \cdot k}{x} \in \mathbb{Z}^{+} \wedge k \in  \mathbb{Z}$
#
# #### **Para $x = 0$:**
#
# Dado que el número cero es el elemento identidad, podemos denotar que:
#
# $$0^{1} = 0 \mod 4 = 0$$
#
# Dado que 1 es el entero positivo más pequeño que permite realizar la operación, se puede concluir que:
#
# $$o(0)=1$$
#
# #### **Para $x = 1$:**
#
# A partir de la fórmula planteada $\dfrac{4 \cdot k}{1} = 4 \cdot k$, podemos denotar lo siguiente:
#
# $$k=1 \Longrightarrow 4 \cdot k  \in \mathbb{Z}^{+} \wedge k \in  \mathbb{Z} $$
#
# Dado que el número entero más pequeño que permite cumplir la condición es $k=1$, se puede concluir que:
#
# $$o(1)=\dfrac{4 \cdot 1}{1} = 4$$
#
# #### **Para $x = 2$:**
#
# A partir de la fórmula planteada $\dfrac{4 \cdot k}{2} = 2 \cdot k$, podemos denotar lo siguiente:
#
# $$k=1 \Longrightarrow 2 \cdot k  \in \mathbb{Z}^{+} \wedge k \in  \mathbb{Z} $$
#
# Dado que el número entero más pequeño que permite cumplir la condición es $k=1$, se puede concluir que:
#
# $$o(2)=\dfrac{2 \cdot 1}{1} = 2$$
#
# #### **Para $x = 3$:**
#
# A partir de la fórmula planteada $\dfrac{4 \cdot k}{3}$, podemos denotar lo siguiente:
#
# $$k=3 \Longrightarrow \dfrac{4 \cdot k}{3}  \in \mathbb{Z}^{+} \wedge k \in  \mathbb{Z} $$
#
# Dado que el número entero más pequeño que permite cumplir la condición es $k=3$, se puede concluir que:
#
# $$o(3)=\dfrac{4 \cdot 3}{3} = 4$$
#
#
# #### Finalmente:
#
#
# \begin{array}{lcl}
#
# \therefore & o(0) = 1 \\
#            & o(1) = 4 \\
#            & o(2) = 2 \\
#            & o(3) = 4 \\
# \end{array}
#
# ### 2. Considerando el grupo de enteros $G=(\mathbb{Z}_5,\oplus)$ encuentre el orden de cada elemento de $\mathbb{Z}_5=\{0,1,2,3,4\}$
#
# Dado que nuestra opración a analizar es la adición módulo 5, podremos escribir la n-ésima operación de un elemento $x$ consigo mismo de la siguiente forma:
#
# \begin{array}{ccccc}
#     x^{n} &=&\underbrace{x \oplus x \oplus x ...}  &=& n\cdot x\mod 5\\
#     && n\text{-veces} && \\
# \end{array}
#
# Adicionalmente, podemos denotar que el elemento identidad sobre nuestra operación es el 0 $(e = 0)$, ya que:
#
# $$\forall_{x \in \mathbb{Z}_5} \,\, x \oplus 0 =  0 \oplus x = x \mod 5$$
#
# El siguiente paso, es describir el orden de cada uno de los elementos de nuestro conjunto. Para esto, vamos a aprovechar la definición de orden y la definición del módulo:
#
# $$o(x) = n \Longleftrightarrow x^{n} = e$$
#
# $$x \mod n = r \Longleftrightarrow \exists_{k \in \mathbb{Z}} \,\, k\cdot n + r = x$$
#
# Para hallar el orden de cada elemento de nuestro conjunto, podemos aplicar lo siguiente:
#
# \begin{array}{rcl}
#     o(x) = n &\Longleftrightarrow& x^{n} = 0 \\
#     & & n\cdot x\mod 5 = 0 \\
#     & & k\cdot 5 + 0 = n \cdot x \\
#     & & \dfrac{5 \cdot k}{x} = n \\
# \end{array}
#
# Se puede concluir que para todo elemento $x \in \mathbb{Z}_5$, su orden se puede describir como el número entero positivo más pequeño que cumpla $\dfrac{5 \cdot k}{x} \in \mathbb{Z}^{+} \wedge k \in  \mathbb{Z}$
#
# #### **Para $x = 0$:**
#
# Dado que el número cero es el elemento identidad, podemos denotar que:
#
# $$0^{1} = 0 \mod 5 = 0$$
#
# Dado que 1 es el entero positivo más pequeño que permite realizar la operación, se puede concluir que:
#
# $$o(0)=1$$
#
# #### **Para $x = 1$:**
#
# A partir de la fórmula planteada $\dfrac{5 \cdot k}{1} = 5 \cdot k$, podemos denotar lo siguiente:
#
# $$k=1 \Longrightarrow 5 \cdot k  \in \mathbb{Z}^{+} \wedge k \in  \mathbb{Z} $$
#
# Dado que el número entero más pequeño que permite cumplir la condición es $k=1$, se puede concluir que:
#
# $$o(1)=\dfrac{5 \cdot 1}{1} = 5$$
#
# #### **Para $x = 2$:**
#
# A partir de la fórmula planteada $\dfrac{5 \cdot k}{2}$, podemos denotar lo siguiente:
#
# $$k=2 \Longrightarrow \dfrac{5 \cdot k}{2}  \in \mathbb{Z}^{+} \wedge k \in  \mathbb{Z} $$
#
# Dado que el número entero más pequeño que permite cumplir la condición es $k=2$, se puede concluir que:
#
# $$o(2)=\dfrac{5 \cdot 2}{2} = 5$$
#
# #### **Para $x = 3$:**
#
# A partir de la fórmula planteada $\dfrac{5 \cdot k}{3}$, podemos denotar lo siguiente:
#
# $$k=3 \Longrightarrow \dfrac{5 \cdot k}{3}  \in \mathbb{Z}^{+} \wedge k \in  \mathbb{Z} $$
#
# Dado que el número entero más pequeño que permite cumplir la condición es $k=3$, se puede concluir que:
#
# $$o(3)=\dfrac{5 \cdot 3}{3} = 5$$
#
# #### **Para $x = 4$:**
#
# A partir de la fórmula planteada $\dfrac{5 \cdot k}{4}$, podemos denotar lo siguiente:
#
# $$k=4 \Longrightarrow \dfrac{5 \cdot k}{4}  \in \mathbb{Z}^{+} \wedge k \in  \mathbb{Z} $$
#
# Dado que el número entero más pequeño que permite cumplir la condición es $k=4$, se puede concluir que:
#
# $$o(3)=\dfrac{5 \cdot 4}{4} = 5$$
#
#
# #### Finalmente:
#
#
# \begin{array}{lcl}
#
# \therefore & o(0) = 1 \\
#            & o(1) = 5 \\
#            & o(2) = 5 \\
#            & o(3) = 5 \\
#            & o(4) = 5
# \end{array}
#
# ### 3. Encuentre el orden de 1 en  $G=(\mathbb{Z},+)$
#
# ### 4. ¿Es $G=(\mathbb{Z}_4,\oplus)$ un grupo cíclico? Si lo es, ¿cuáles son sus generadores?
#
# Para determinar que $G$ es un grupo cíclico debemos determinar si existe un elemento tal que
#
# $$\langle x \rangle = \{nx \mod 5 : n\in \mathbb{Z}\} = \mathbb{Z}_4$$
#
# No es necesario ser muy metódicos para denotar que $x=1$ es un valor que cumple esta propiedad, solo es necesario evaluarlo en los 4 casos más simples para hacerlo visible:
#
# \begin{array}{cccc}
#     1^{1} &=& 1 \mod 4 &=& 1\\
#     1^{2} &=& 2 \mod 4 &=& 2\\
#     1^{3} &=& 3 \mod 4 &=& 3\\
#     1^{4} &=& 4 \mod 4 &=& 0\\
# \end{array}
#
# $$\langle 1 \rangle = \{0,1,2,3\} = \mathbb{Z}_4$$
#
# Con este proceso, hemos denotado que $G$ es un grupo cíclico. El siguiente paso es determinar todos sus posibles generadores. Para ello, vamos a apoyarnos de la siguiente propiedad:
#
# $$G = \langle x \rangle \Longrightarrow o(x) = |G|$$
#
# Y su respectiva contrarreciproca:
#
# $$o(x) \neq |G|  \Longrightarrow G \neq \langle x \rangle$$
#
# A partir de esto, podemos descartar y determinar posibles candidatos para ser generadores de $G$. A partir de este criterio, podemos descartar $x = 0 \wedge x = 2$; y tendriamos de candidatos a $x = 1 \wedge x = 3$
#
# Con el procedimiento anterior ya demostramos que $x=1$ es un generador de $G$. El siguiente paso es realizar el mismo proceso para $x=3$
#
# \begin{array}{cccc}
#     3^{1} &=& 3 \mod 4 &=& 3\\
#     3^{2} &=& 6 \mod 4 &=& 2\\
#     3^{3} &=& 9 \mod 4 &=& 1\\
#     3^{4} &=& 12 \mod 4 &=& 0\\
# \end{array}
#
# $$\langle 3 \rangle = \{0,1,2,3\} = \mathbb{Z}_4$$
#
# Con ese proceso, se puede concluir que $x=3$ también es un generador de $G$.
#
# \begin{array}{lcl}
#
# \therefore & G\text{ es un grupo cíclico} \\
#            & \text{Gen}(G) = \{1,3\}
# \end{array}
